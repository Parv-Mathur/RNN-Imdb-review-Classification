# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
#sentences
sent = ['the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good'
        ]

# %%
voc_size = 10000

# %%
#OneHot representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[6679, 3694, 4702, 1055],
#  [6679, 3694, 4702, 532],
#  [6679, 6796, 4702, 6545],
#  [7786, 8276, 5776, 212, 6507],
#  [7786, 8276, 5776, 212, 1642],
#  [4570, 6679, 6171, 4702, 2334],
#  [35, 7999, 9523, 212]]

# %%
# word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
#pre--> 0's before
#post--> 0's after
# Out:
# [[   0    0    0    0 6679 3694 4702 1055]
#  [   0    0    0    0 6679 3694 4702  532]
#  [   0    0    0    0 6679 6796 4702 6545]
#  [   0    0    0 7786 8276 5776  212 6507]
#  [   0    0    0 7786 8276 5776  212 1642]
#  [   0    0    0 4570 6679 6171 4702 2334]
#  [   0    0    0    0   35 7999 9523  212]]

# %%
#feature representation
import warnings
warnings.filterwarnings('ignore')
dim=10
model=Sequential()
model.add(Embedding(voc_size,dim,input_length = sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# array([[[-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [ 0.02985242,  0.01682505,  0.01179092, -0.00236138,
#          -0.04421041, -0.04599836, -0.04327399,  0.04772845,
#          -0.03457483,  0.03139849],
#         [-0.04228169,  0.02984026, -0.04170866, -0.0230161 ,
#           0.00198343,  0.04518194,  0.03290286,  0.00222676,
#           0.02583719,  0.03704958],
#         [ 0.01096068,  0.00740035,  0.04367678,  0.04411683,
#           0.01690408, -0.02242893, -0.04850506, -0.03039612,
#          -0.02709704,  0.02693608],
#         [ 0.02360988, -0.03598008, -0.0415429 , -0.00424843,
#           0.01337286, -0.0119115 , -0.00259515, -0.03979338,
#          -0.01157966, -0.04826992]],
#
#        [[-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [ 0.02985242,  0.01682505,  0.01179092, -0.00236138,
#          -0.04421041, -0.04599836, -0.04327399,  0.04772845,
#          -0.03457483,  0.03139849],
#         [-0.04228169,  0.02984026, -0.04170866, -0.0230161 ,
#           0.00198343,  0.04518194,  0.03290286,  0.00222676,
#           0.02583719,  0.03704958],
#         [ 0.01096068,  0.00740035,  0.04367678,  0.04411683,
#           0.01690408, -0.02242893, -0.04850506, -0.03039612,
#          -0.02709704,  0.02693608],
#         [-0.0197246 ,  0.04100548,  0.03652741, -0.02914654,
#           0.04501194, -0.01134912,  0.03984152, -0.02234092,
#           0.02664919, -0.01924462]],
#
#        [[-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [ 0.02985242,  0.01682505,  0.01179092, -0.00236138,
#          -0.04421041, -0.04599836, -0.04327399,  0.04772845,
#          -0.03457483,  0.03139849],
#         [ 0.0002255 ,  0.00396397,  0.03914012,  0.01367117,
#           0.01594586,  0.03529835, -0.02573799,  0.0360096 ,
#          -0.00495865, -0.00683356],
#         [ 0.01096068,  0.00740035,  0.04367678,  0.04411683,
#           0.01690408, -0.02242893, -0.04850506, -0.03039612,
#          -0.02709704,  0.02693608],
#         [ 0.0267256 ,  0.00297636, -0.01184635, -0.04727886,
#           0.04445528,  0.03851945, -0.01763014,  0.00454734,
#          -0.03829652,  0.01567539]],
#
#        [[-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.02826895,  0.02948264,  0.00066743,  0.02779205,
#           0.03436616, -0.03981649, -0.04125595, -0.0451633 ,
#          -0.01098815,  0.00198159],
#         [-0.01833791, -0.03616235, -0.00084803,  0.01120033,
#          -0.01395881, -0.04108975, -0.04465249, -0.04390358,
#          -0.02788254,  0.0404715 ],
#         [-0.00266063, -0.01698757, -0.00636157,  0.02694613,
#           0.04563837,  0.01641191,  0.00359082,  0.03655219,
#           0.04278621,  0.02538753],
#         [ 0.04749104, -0.01165356,  0.0418193 , -0.0328454 ,
#           0.03518156, -0.006204  , -0.02023098,  0.01190852,
#          -0.00365378, -0.04086658],
#         [-0.02917337,  0.04087157,  0.00784357, -0.00165563,
#          -0.03182168,  0.04224148,  0.01917663, -0.04912454,
#           0.02826751,  0.03799007]],
#
#        [[-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.02826895,  0.02948264,  0.00066743,  0.02779205,
#           0.03436616, -0.03981649, -0.04125595, -0.0451633 ,
#          -0.01098815,  0.00198159],
#         [-0.01833791, -0.03616235, -0.00084803,  0.01120033,
#          -0.01395881, -0.04108975, -0.04465249, -0.04390358,
#          -0.02788254,  0.0404715 ],
#         [-0.00266063, -0.01698757, -0.00636157,  0.02694613,
#           0.04563837,  0.01641191,  0.00359082,  0.03655219,
#           0.04278621,  0.02538753],
#         [ 0.04749104, -0.01165356,  0.0418193 , -0.0328454 ,
#           0.03518156, -0.006204  , -0.02023098,  0.01190852,
#          -0.00365378, -0.04086658],
#         [ 0.04117577,  0.01916231,  0.00720973,  0.03616376,
#          -0.0321692 ,  0.02295849, -0.01992788,  0.00490962,
#           0.02146183,  0.01264994]],
#
#        [[-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.02088125,  0.00855041, -0.00905799, -0.02889568,
#          -0.02923212,  0.04872367, -0.02449693,  0.03451588,
#           0.00043832, -0.00857011],
#         [ 0.02985242,  0.01682505,  0.01179092, -0.00236138,
#          -0.04421041, -0.04599836, -0.04327399,  0.04772845,
#          -0.03457483,  0.03139849],
#         [-0.01804236, -0.02238256,  0.02318205, -0.00891297,
#          -0.01682457, -0.04066477,  0.01764175, -0.02050917,
#          -0.03433031,  0.04114513],
#         [ 0.01096068,  0.00740035,  0.04367678,  0.04411683,
#           0.01690408, -0.02242893, -0.04850506, -0.03039612,
#          -0.02709704,  0.02693608],
#         [-0.02486842,  0.03011348,  0.01139002,  0.04890868,
#          -0.04557696, -0.04397314, -0.00419972,  0.03045904,
#           0.03045323,  0.0311275 ]],
#
#        [[-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [-0.04231029, -0.01746891, -0.03974367, -0.0368989 ,
#          -0.00983615, -0.02180582,  0.01149612,  0.02720268,
#           0.02691281, -0.01148782],
#         [ 0.02144207, -0.00372751, -0.02597645,  0.00224414,
#          -0.0329142 ,  0.00462944, -0.01813891, -0.0254606 ,
#          -0.01209604, -0.03405104],
#         [ 0.00230766,  0.00948638,  0.02807775, -0.00799412,
#          -0.0050924 , -0.0199397 ,  0.02427584, -0.03015037,
#          -0.01397911,  0.00432634],
#         [-0.0013229 ,  0.04436078, -0.03519224,  0.01348967,
#           0.03474602,  0.04730305,  0.01739308, -0.02196454,
#           0.03205642, -0.04935063],
#         [ 0.04749104, -0.01165356,  0.0418193 , -0.0328454 ,
#           0.03518156, -0.006204  , -0.02023098,  0.01190852,
#          -0.00365378, -0.04086658]]], dtype=float32)
